# %% [markdown]
# <a href="https://colab.research.google.com/github/Mansur51-hub/Digcul/blob/main/HW1_Graph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import networkx as nx
import graphviz as gr

G_ = nx.Graph()

# %%
with open('list.txt') as file:
  text = file.read().split("\n")
for s in text:
  G_.add_node(s)

# %%
with open('land.txt') as file:
  text = file.read().split("\n")
for s in text:
  v = s.split(" ")
  G_.add_edge(v[0], v[1])


G = G_
G.remove_nodes_from(["UK", "Ireland", "Iceland", "Malta", "Cyprus"])


print("|V| = ", G.number_of_nodes())
print("|E| = ", G.number_of_edges())
# Out:
# |V| =  42
# |E| =  87

# %%
deq = dict(G.degree)
deq_vertex = list(deq.keys())
deq_deq = list(deq.values())
for i in range(42):
  print("deq(",deq_vertex[i],") =", deq_deq[i])
print("Δ(G) =", max(dict(nx.degree(G)).values()))
print("𝛿(G) =", min(dict(nx.degree(G)).values()))
print(nx.eccentricity(G))
print("rad(G) =", nx.algorithms.radius(G))
print("diam(G) =", nx.algorithms.distance_measures.diameter(G))
print("center(G) =", nx.center(G))
print("all minimum cycles =", nx.minimum_cycle_basis(G))
print("girth(G) =", 3)
print(nx.minimum_edge_cut(G))
print(nx.minimum_node_cut(G))
print("𝜅(G) = 1")
print("𝜆(G) = 1")
# Out:
# deq( Albania ) = 4
# deq( Andorra ) = 2
# deq( Austria ) = 8
# deq( Belarus ) = 5
# deq( Belgium ) = 4
# deq( Bosnia ) = 3
# deq( Bulgaria ) = 5
# deq( Croatia ) = 5
# deq( Czech ) = 4
# deq( Denmark ) = 1
# deq( Estonia ) = 2
# deq( Finland ) = 3
# deq( France ) = 8
# deq( Germany ) = 9
# deq( Greece ) = 4
# deq( Hungary ) = 7
# deq( Italy ) = 6
# deq( Kosovo ) = 4
# deq( Latvia ) = 4
# deq( Liechtenstein ) = 2
# deq( Lithuania ) = 4
# deq( Luxembourg ) = 3
# deq( Macedonia ) = 5
# deq( Moldova ) = 2
# deq( Monaco ) = 1
# deq( Montenegro ) = 5
# deq( Netherlands ) = 2
# deq( Norway ) = 3
# deq( Poland ) = 7
# deq( Portugal ) = 1
# deq( Romania ) = 5
# deq( Russia ) = 8
# deq( San-Marino ) = 1
# deq( Serbia ) = 8
# deq( Slovakia ) = 5
# deq( Slovenia ) = 4
# deq( Spain ) = 3
# deq( Sweden ) = 2
# deq( Switzerland ) = 5
# deq( Turkey ) = 2
# deq( Ukraine ) = 7
# deq( Vatican ) = 1
# Δ(G) = 9
# 𝛿(G) = 1
# {'Albania': 7, 'Andorra': 7, 'Austria': 5, 'Belarus': 5, 'Belgium': 6, 'Bosnia': 6, 'Bulgaria': 7, 'Croatia': 5, 'Czech': 5, 'Denmark': 6, 'Estonia': 6, 'Finland': 6, 'France': 6, 'Germany': 5, 'Greece': 8, 'Hungary': 5, 'Italy': 6, 'Kosovo': 7, 'Latvia': 6, 'Liechtenstein': 6, 'Lithuania': 6, 'Luxembourg': 6, 'Macedonia': 7, 'Moldova': 6, 'Monaco': 7, 'Montenegro': 6, 'Netherlands': 6, 'Norway': 6, 'Poland': 5, 'Portugal': 8, 'Romania': 6, 'Russia': 5, 'San-Marino': 7, 'Serbia': 6, 'Slovakia': 5, 'Slovenia': 5, 'Spain': 7, 'Sweden': 7, 'Switzerland': 5, 'Turkey': 8, 'Ukraine': 5, 'Vatican': 7}
# rad(G) = 5
# diam(G) = 8
# center(G) = ['Austria', 'Belarus', 'Croatia', 'Czech', 'Germany', 'Hungary', 'Poland', 'Russia', 'Slovakia', 'Slovenia', 'Switzerland', 'Ukraine']
# all minimum cycles = [['Bulgaria', 'Macedonia', 'Serbia'], ['Bulgaria', 'Macedonia', 'Greece'], ['Croatia', 'Bosnia', 'Serbia'], ['Croatia', 'Serbia', 'Hungary'], ['Croatia', 'Montenegro', 'Bosnia'], ['Germany', 'Austria', 'Czech'], ['Austria', 'Czech', 'Slovakia'], ['Russia', 'Latvia', 'Estonia'], ['France', 'Belgium', 'Luxembourg'], ['France', 'Belgium', 'Germany'], ['France', 'Germany', 'Switzerland'], ['France', 'Switzerland', 'Italy'], ['France', 'Andorra', 'Spain'], ['Poland', 'Germany', 'Czech'], ['Germany', 'Austria', 'Switzerland'], ['Belgium', 'Germany', 'Luxembourg'], ['Belgium', 'Netherlands', 'Germany'], ['Macedonia', 'Albania', 'Greece'], ['Turkey', 'Bulgaria', 'Greece'], ['Ukraine', 'Romania', 'Hungary'], ['Ukraine', 'Hungary', 'Slovakia'], ['Austria', 'Hungary', 'Slovakia'], ['Croatia', 'Slovenia', 'Hungary'], ['Slovenia', 'Austria', 'Hungary'], ['Slovenia', 'Austria', 'Italy'], ['Austria', 'Switzerland', 'Italy'], ['Macedonia', 'Serbia', 'Kosovo'], ['Macedonia', 'Kosovo', 'Albania'], ['Montenegro', 'Kosovo', 'Albania'], ['Latvia', 'Lithuania', 'Belarus'], ['Russia', 'Latvia', 'Belarus'], ['Austria', 'Switzerland', 'Liechtenstein'], ['Poland', 'Lithuania', 'Belarus'], ['Russia', 'Lithuania', 'Belarus'], ['Montenegro', 'Serbia', 'Kosovo'], ['Ukraine', 'Moldova', 'Romania'], ['Montenegro', 'Bosnia', 'Serbia'], ['Sweden', 'Finland', 'Norway'], ['Russia', 'Finland', 'Norway'], ['Poland', 'Czech', 'Slovakia'], ['Poland', 'Russia', 'Belarus'], ['Poland', 'Ukraine', 'Belarus'], ['Romania', 'Serbia', 'Hungary'], ['Bulgaria', 'Serbia', 'Romania'], ['Russia', 'Ukraine', 'Belarus'], ['Poland', 'Ukraine', 'Slovakia']]
# girth(G) = 3
# {('Denmark', 'Germany')}
# {'Germany'}
# 𝜅(G) = 1
# 𝜆(G) = 1

# %%
import matplotlib.pyplot as plt
import numpy as np

ans = 0

all_cliques = list(nx.find_cliques(G))
maximal_clique = []
for i in all_cliques:
  if(ans < len(i)):
    ans = len(i)
    maximal_clique = i
print(maximal_clique)
# Out:
# ['Belarus', 'Russia', 'Poland', 'Lithuania']

# %%
max_size_of_independent_set = 0
maximal_independet_set = []
for i in range(1000):
    current_independent_set = nx.maximal_independent_set(G)
    if(max_size_of_independent_set < len(current_independent_set)):
       max_size_of_independent_set = len(current_independent_set)
       maximal_independet_set = current_independent_set  
print("|Stable set| =", max_size_of_independent_set)
print("Stable set =", maximal_independet_set)
# Out:
# |Stable set| = 18
# Stable set = ['Ukraine', 'Bosnia', 'Luxembourg', 'San-Marino', 'Portugal', 'Netherlands', 'Sweden', 'Turkey', 'Lithuania', 'Switzerland', 'Andorra', 'Kosovo', 'Slovenia', 'Vatican', 'Denmark', 'Czech', 'Estonia', 'Monaco']

# %%
max_size_of_matching = 0
maximal_matching = []

for i in range(1000):
  current_matching = nx.maximal_matching(G)
  if(max_size_of_matching < len(current_matching)):
    max_size_of_matching = len(current_matching)
    maximal_matching = current_matching

print("|Matching| =", max_size_of_matching)
print("Matching =", maximal_matching)
# Out:
# |Matching| = 17
# Matching = {('Albania', 'Kosovo'), ('Czech', 'Poland'), ('Belarus', 'Russia'), ('Belgium', 'Netherlands'), ('Bosnia', 'Croatia'), ('Finland', 'Norway'), ('Portugal', 'Spain'), ('Hungary', 'Ukraine'), ('Liechtenstein', 'Switzerland'), ('Estonia', 'Latvia'), ('Andorra', 'France'), ('Bulgaria', 'Romania'), ('Greece', 'Macedonia'), ('Austria', 'Slovakia'), ('Italy', 'Slovenia'), ('Montenegro', 'Serbia'), ('Denmark', 'Germany')}

# %%
min_edge_cover = nx.min_edge_cover(G)
print("|min_edge_cover| =", len(min_edge_cover))
print(min_edge_cover)
# Out:
# |min_edge_cover| = 27
# {('Belgium', 'Netherlands'), ('San-Marino', 'Italy'), ('Hungary', 'Slovenia'), ('Spain', 'Portugal'), ('Denmark', 'Germany'), ('Liechtenstein', 'Austria'), ('Czech', 'Slovakia'), ('Bosnia', 'Serbia'), ('Macedonia', 'Greece'), ('Monaco', 'France'), ('Germany', 'Denmark'), ('Belarus', 'Ukraine'), ('Italy', 'San-Marino'), ('Luxembourg', 'Germany'), ('Estonia', 'Latvia'), ('Montenegro', 'Croatia'), ('France', 'Andorra'), ('Austria', 'Switzerland'), ('France', 'Monaco'), ('Poland', 'Lithuania'), ('Moldova', 'Romania'), ('Turkey', 'Bulgaria'), ('Norway', 'Russia'), ('Austria', 'Liechtenstein'), ('Vatican', 'Italy'), ('Kosovo', 'Albania'), ('Sweden', 'Finland')}

# %%
blocks = nx.biconnected_component_edges(G)

for i in list(blocks):
  print(i)

print(list(nx.articulation_points(G)))
# Out:
# [('Russia', 'Finland'), ('Finland', 'Norway'), ('Norway', 'Sweden'), ('Sweden', 'Finland'), ('Norway', 'Russia')]
# [('Spain', 'Portugal')]
# [('France', 'Andorra'), ('Andorra', 'Spain'), ('Spain', 'France')]
# [('Italy', 'Vatican')]
# [('Italy', 'San-Marino')]
# [('France', 'Monaco')]
# [('Germany', 'Denmark')]
# [('Albania', 'Kosovo'), ('Kosovo', 'Serbia'), ('Serbia', 'Bosnia'), ('Bosnia', 'Croatia'), ('Croatia', 'Serbia'), ('Croatia', 'Slovenia'), ('Slovenia', 'Austria'), ('Austria', 'Slovakia'), ('Slovakia', 'Czech'), ('Czech', 'Austria'), ('Czech', 'Poland'), ('Poland', 'Belarus'), ('Belarus', 'Russia'), ('Russia', 'Estonia'), ('Estonia', 'Latvia'), ('Latvia', 'Belarus'), ('Latvia', 'Lithuania'), ('Lithuania', 'Belarus'), ('Lithuania', 'Poland'), ('Lithuania', 'Russia'), ('Latvia', 'Russia'), ('Russia', 'Poland'), ('Russia', 'Ukraine'), ('Ukraine', 'Belarus'), ('Ukraine', 'Hungary'), ('Hungary', 'Austria'), ('Hungary', 'Croatia'), ('Hungary', 'Romania'), ('Romania', 'Bulgaria'), ('Bulgaria', 'Serbia'), ('Bulgaria', 'Macedonia'), ('Macedonia', 'Albania'), ('Macedonia', 'Greece'), ('Greece', 'Albania'), ('Greece', 'Bulgaria'), ('Greece', 'Turkey'), ('Turkey', 'Bulgaria'), ('Macedonia', 'Kosovo'), ('Macedonia', 'Serbia'), ('Romania', 'Moldova'), ('Moldova', 'Ukraine'), ('Romania', 'Ukraine'), ('Romania', 'Serbia'), ('Hungary', 'Slovakia'), ('Hungary', 'Serbia'), ('Hungary', 'Slovenia'), ('Ukraine', 'Poland'), ('Ukraine', 'Slovakia'), ('Poland', 'Germany'), ('Germany', 'Austria'), ('Germany', 'Belgium'), ('Belgium', 'Netherlands'), ('Netherlands', 'Germany'), ('Belgium', 'France'), ('France', 'Luxembourg'), ('Luxembourg', 'Belgium'), ('Luxembourg', 'Germany'), ('France', 'Germany'), ('France', 'Switzerland'), ('Switzerland', 'Austria'), ('Switzerland', 'Germany'), ('Switzerland', 'Italy'), ('Italy', 'Austria'), ('Italy', 'France'), ('Italy', 'Slovenia'), ('Switzerland', 'Liechtenstein'), ('Liechtenstein', 'Austria'), ('Germany', 'Czech'), ('Poland', 'Slovakia'), ('Croatia', 'Montenegro'), ('Montenegro', 'Albania'), ('Montenegro', 'Bosnia'), ('Montenegro', 'Kosovo'), ('Montenegro', 'Serbia')]
# ['Russia', 'Spain', 'France', 'Italy', 'Germany']

# %%
components = nx.biconnected_components(G)

for i in list(components):
  print(i)
# Out:
# {'Sweden', 'Finland', 'Norway', 'Russia'}
# {'Spain', 'Portugal'}
# {'France', 'Andorra', 'Spain'}
# {'Vatican', 'Italy'}
# {'San-Marino', 'Italy'}
# {'France', 'Monaco'}
# {'Denmark', 'Germany'}
# {'Moldova', 'Austria', 'Belarus', 'Poland', 'Germany', 'Croatia', 'Belgium', 'Ukraine', 'Bosnia', 'Estonia', 'Czech', 'Luxembourg', 'Bulgaria', 'Albania', 'Macedonia', 'Slovenia', 'Serbia', 'Hungary', 'Netherlands', 'Russia', 'Latvia', 'Montenegro', 'Romania', 'Lithuania', 'Switzerland', 'Greece', 'Turkey', 'Italy', 'France', 'Liechtenstein', 'Kosovo', 'Slovakia'}

# %%
Graph_weighted = nx.Graph()

with open('distance.txt') as file:
    text = file.read().split("\n")
    for s in text:
      edge = s.split(" ")
      Graph_weighted.add_edge(edge[0], edge[1], weight = float(edge[2]))

MST = nx.minimum_spanning_tree(Graph_weighted)

plt.figure(figsize=(25,25))
nx.draw_networkx(MST)

# %%
prufier_code = []
T = nx.Graph()

for edge in MST.edges:
  T.add_edge(list(MST.nodes).index(edge[0]),list(MST.nodes).index(edge[1]))
prufier_code = nx.to_prufer_sequence(T)
print(len(prufier_code))
print(prufier_code)
# Out:
# 40
# [4, 9, 8, 20, 23, 23, 6, 26, 2, 3, 15, 16, 8, 21, 20, 17, 36, 34, 18, 17, 22, 40, 6, 12, 12, 10, 30, 29, 3, 1, 4, 26, 27, 10, 8, 13, 14, 6, 5, 7]
